# %% [markdown]
# ## Code

# %% [markdown]
# ```
# import cv2
# import sys
#
# s = 0
# if len(sys.argv) > 1:
#     s = sys.argv[1]
#
# source = cv2.VideoCapture(s)
#
# win_name = 'Camera Preview'
# cv2.namedWindow(win_name, cv2.WINDOW_NORMAL)
#
# while cv2.waitKey(1) != 27: # Escape
#     has_frame, frame = source.read()
#     if not has_frame:
#         break
#     cv2.imshow(win_name, frame)
#
# source.release()
# cv2.destroyWindow(win_name)
# ```

# %% [markdown]
# ```
# import cv2 as cv
#
# # # Reading Images
# # img1 = cv.imread("Photos/cat.jpg")
# # # cv.imshow("Cat", img1)
# #
# #
# # img2 = cv.imread("Photos/cat_large.jpg")
# # # cv.imshow("Cat Large", img2)
# # cv.waitKey(0) # 0: waits for infinite amount of time, until key is pressed; 1000: 1 second
#
#
# # =====================================================================================================================
#
# # # Reading Videos # https://docs.opencv.org/4.x/d8/dfe/classcv_1_1VideoCapture.html#a31e7cf5ba9debaec15437a200b18241e
# # vid1 = cv.VideoCapture(0) # 0: default laptop camera, 1: first cam connected to computer, and so on
#
# vid1 = cv.VideoCapture("Videos/dog.mp4") # to read videos from existing file paths. vid1 is an instance of the VideoCapture class
# while True:
#     # here we get the video, frame by frame, using read method
#     isTrue, frame = vid1.read() # https://docs.opencv.org/4.x/dd/d43/tutorial_py_video_display.html
#     print(isTrue)
#     # we display each frame using cv.imshow method
#     cv.imshow("Dog Video", frame)
#     if cv.waitKey(20) & 0xFF==ord('d'):
#         break
#     """ The line of code waits for a key press for 20 milliseconds.
#         If the key pressed is 'd', the loop (or the program) will break and stop execution.
#     """
# # cv2.error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
# # after the last frame, it doesn't find more frames in that path
# vid1.release()
# cv.destroyAllWindows()
# ```

# %% [markdown]
# ## Questions

# %% [markdown]
# #### 1. What is the correct way to release the resources used by `cv2.VideoCapture()` when done with the webcam?
#
# - `cap.release()`

# %% [markdown]
# #### 2. What is the recommended way to handle errors when using `cv2.VideoCapture()` with a webcam?
#
# - Use try and except blocks to catch errors

# %% [markdown]
# #### 3. What is the purpose of `cv2.waitKey(1) != 27` in OpenCV?
#
# - To check if the `esc` key has been pressed
